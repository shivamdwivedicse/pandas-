# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **CREATING A DATAFRAME**

# %%
data = {
    "Name" : ['john','anna','peter','linda'],
    'Age': [28,34,29,42],
    'City':['New York', 'Paris' , 'Berlin' , 'London'],
    "Salary":[65000,70000,62000,85000]
}
#Combining muntiple series is known as dataframe.
#use this data to create dataframe
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   anna   34     Paris   70000
# 2  peter   29    Berlin   62000
# 3  linda   42    London   85000

# %%
#Using list
data_list = [
    ['john' , 28 , 'New York' , 65000],
    ['Anna' , 34 , 'Paris' , 70000],
    ['Peter' , 29 , 'Berlin' , 62000],
    ['Linda' , 42 , 'London' , 85000],
]
columns = ["Name","Age","City","Salary"]

df2 = pd.DataFrame(data_list , columns = columns)

df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **SELECTION AND INDEXING OF COLUMNS**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#select name:
df2["Name"]
# Out:
# 0     john
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
#Targeting muntiple columns:
#Make list of list and target Ex:-
df2[["Name","City"]]
# Out:
#     Name      City
# 0   john  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **CREATING A NEW COLUMN**

# %%
#lets create a new column in df2 as Designation:
df2["Designation"] = ["Doctor","Engenieer","Professor","Data Scientist"]
df2
# Out:
#     Name  Age      City  Salary     Designation
# 0   john   28  New York   65000          Doctor
# 1   Anna   34     Paris   70000       Engenieer
# 2  Peter   29    Berlin   62000       Professor
# 3  Linda   42    London   85000  Data Scientist

# %%
df2
# Out:
#     Name  Age      City  Salary     Designation
# 0   john   28  New York   65000          Doctor
# 1   Anna   34     Paris   70000       Engenieer
# 2  Peter   29    Berlin   62000       Professor
# 3  Linda   42    London   85000  Data Scientist

# %% [markdown]
# **REMOVING A COLUMN**

# %%
#lets Remove designation:
# df2.drop("Designation", axis = 1) 
df2.drop("Designation", axis = 1,inplace = True) 

# drop don't remove designation from main data it only remove designation and show a copy
#To completly remove Designation from data use 'inplace = True'

# %%
df2 #in main database designation  is present, after using inplace it will not present anymore
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#to remove row make axis = 0

# %% [markdown]
# **SELECTING ROWS**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          john
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %% [markdown]
# **SELECTING SUBSETS OF ROWS AND COLUMNS**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  peter   29
# 3  linda   42

# %% [markdown]
# **CONDITIONAL SELECTION**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# I only want to  see those peoples whose age is above 30
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#i only want people whose age is above 30 and their city must be paris 
df2[(df2['Age'] >30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
